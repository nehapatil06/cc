# %%
def medical_expert_system(): 
    print("Hospital Expert System") 
    print("Enter your symptoms (yes/no)") 
    fever = input("Do you have fever? ") 
    cough = input("Do you have cough? ") 
    headache = input("Do you have headache? ") 
    stomach_pain = input("Do you have stomach pain? ") 
 
    if fever == "yes" and cough == "yes": 
        print("Possible Disease: Flu") 
        print("Advice: Take rest and consult a doctor.") 
    elif fever == "yes" and headache == "yes": 
        print("Possible Disease: Viral Fever") 
        print("Advice: Drink fluids and visit a physician.") 
    elif stomach_pain == "yes": 
        print("Possible Disease: Gastric Problem") 
        print("Advice: Avoid spicy food and consult a doctor.") 
    else: 
        print("Symptoms unclear. Please consult a doctor.") 
medical_expert_system()
# Out:
# Hospital Expert System
# Enter your symptoms (yes/no)
# Do you have fever?  yes
# Do you have cough?  no
# Do you have headache?  yes
# Do you have stomach pain?  no
# Possible Disease: Viral Fever
# Advice: Drink fluids and visit a physician.
