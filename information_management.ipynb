# %%
def information_management_expert_system():
    print("Information Management Expert System")
    print("Select the type of information problem:")
    print("1. File storage issue")
    print("2. Data backup problem")
    print("3. Document search problem")
    print("4. Data security issue")

    choice = int(input("Enter problem number (1-4): "))

    if choice == 1:
        print("Solution: Organize files into proper folders and use cloud storage.")
    elif choice == 2:
        print("Solution: Use automatic backup systems or cloud backup services.")
    elif choice == 3:
        print("Solution: Use keywords, tags, or metadata to search documents quickly.")
    elif choice == 4:
        print("Solution: Use encryption, strong passwords, and access control.")
    else:
        print("Invalid choice. Please try again.")


information_management_expert_system()
# Out:
# Information Management Expert System
# Select the type of information problem:
# 1. File storage issue
# 2. Data backup problem
# 3. Document search problem
# 4. Data security issue
# Enter problem number (1-4):  1
# Solution: Organize files into proper folders and use cloud storage.
