# %%
def employee_expert_system(): 
    print("Employee Performance Evaluation System") 
    attendance = int(input("Enter attendance percentage: ")) 
    work_quality = input("Work quality (excellent/good/average): ") 
    punctuality = input("Is employee punctual? (yes/no): ") 
 
    if attendance > 90 and work_quality == "excellent" and punctuality == "yes": 
        print("Performance: Outstanding") 
 
    elif attendance > 75 and work_quality == "good": 
        print("Performance: Good") 
 
    elif attendance > 60 and work_quality == "average": 
        print("Performance: Average") 
    else: 
        print("Performance: Needs Improvement") 
 
employee_expert_system()
# Out:
# Employee Performance Evaluation System
# Enter attendance percentage:  65
# Work quality (excellent/good/average):  good
# Is employee punctual? (yes/no):  no
# Performance: Needs Improvement
