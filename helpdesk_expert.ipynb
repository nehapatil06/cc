# %%
def helpdesk_expert_system(): 
    print("Help Desk Expert System") 
    print("Select your problem:") 
    print("1. Computer not starting") 
    print("2. Internet not working") 
    print("3. Printer not printing") 
    print("4. Slow computer") 
 
    choice = int(input("Enter problem number: ")) 
    if choice == 1: 
        print("Solution: Check power supply and restart the computer.") 
    elif choice == 2: 
        print("Solution: Check router connection and network cable.") 
    elif choice == 3: 
        print("Solution: Check printer connection and install printer driver.") 
    elif choice == 4: 
        print("Solution: Close unused programs and scan for viruses.") 
    else: 
        print("Invalid choice. Contact technical support.") 
helpdesk_expert_system()
# Out:
# Help Desk Expert System
# Select your problem:
# 1. Computer not starting
# 2. Internet not working
# 3. Printer not printing
# 4. Slow computer
# Enter problem number:  1
# Solution: Check power supply and restart the computer.
