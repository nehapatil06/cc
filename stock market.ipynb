# %%
def stock_expert_system(): 
    print("Stock Market Expert System") 
    price = input("Enter stock price level (low/medium/high): ") 
    trend = input("Enter market trend (up/down/stable): ") 
 
    if price == "low" and trend == "up": 
        print("Advice: Buy the stock") 
elif price == "high" and trend == "down": 
 
 
        print("Advice: Sell the stock") 
    elif trend == "stable": 
        print("Advice: Hold the stock") 
    else: 
        print("Advice: Monitor market before making decision") 
 
stock_expert_system()
